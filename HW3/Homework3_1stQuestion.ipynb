# %% [markdown]
# # 1st&2nd Questions

# %%
#import libraries
from __future__ import print_function
import pylab as pl
import numpy as np

# %pylab inline
# %matplotlib
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using matplotlib backend: Qt4Agg
# WARNING: pylab import has clobbered these variables: ['norm']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#define mean
mymean = 100

# %%
#create empty dictionary
md={}
# add objects
md['chisq'] = np.random.chisquare(mymean, size=100)
md['normal'] = np.random.normal(mymean,1,100)
md['poisson'] = np.random.poisson(mymean,100)
md['binomial'] = np.random.binomial(mymean,0.5,100)
md['stdgamma'] = np.random.standard_gamma(mymean,100)
md['gm'] = np.random.gumbel(mymean,1,100)

# %%
#plot the histogram for 'chisq'
# %pylab inline
pl.hist(md['chisq'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# chi square distribution values change between the 70-140 and most of the values gether around the mean.

# %%
#plot the histogram for 'normal'
# %pylab inline
pl.hist(md['normal'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In normal distribution values cloases the mean.

# %%
#plot the histogram for 'poisson'
# %pylab inline
pl.hist(md['poisson'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In poisson distribution values come together around the mean, distributioın becomes left skewed behaviour

# %%
#plot the histogram for 'binomial'
# %pylab inline
pl.hist(md['binomial'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In binomial distribution values become distributed between the 40 and 65 distribution values are change

# %%
#plot the histogram for 'stdgamma'
# %pylab inline
pl.hist(md['stdgamma'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# In normal distribution values closes the mean but mainly distribute around the mean.

# %%
#plot the histogram for 'gumbel'
# %pylab inline
pl.hist(md['gm'], bins=30)
pl.ylabel('N')
pl.xlabel('x')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Explanations are at the end of the plots

# %% [markdown]
#  # 3rd Question

# %%
#define the size, interval and number of distribution 
sizes=2000/(np.array(range(1,100)+[10]))

# %%
#redefine the dictionary
md['chisq']={}

# %%
# creating a loop
for n in sizes:
    md['chisq'][n]= np.random.chisquare(mymean, n)

# %%
#calculate the means
means = {}
means['chisq'] = {}

# %%
#plot the distribution
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['chisq'].iterkeys():
    means['chisq'][nn] = md['chisq'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['chisq'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
#plotting the means
allmeans=[]
for n in means['chisq']:
    allmeans.append(means['chisq'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
#normal distribution
#do the same calculations for normal distribution 
sizes=2000/(np.array(range(1,100)+[10]))

# %%
md['normal']={}

# %%
for n in sizes:
    md['normal'][n]= np.random.normal(mymean,1,100)

# %%
means = {}
means['normal'] = {}

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['normal'].iterkeys():
    means['normal'][nn] = md['normal'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['normal'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['normal']:
    allmeans.append(means['normal'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
#poisson distribution
#do the same calculations for poisson distribution

sizes=2000/(np.array(range(1,100)+[10]))

# %%
md['poisson']={}

# %%
for n in sizes:
    md['poisson'][n]= np.random.poisson(mymean,100)

# %%
means = {}
means['poisson'] = {}

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['poisson'].iterkeys():
    means['poisson'][nn] = md['poisson'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['poisson'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['poisson']:
    allmeans.append(means['poisson'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
#binomial distribution
#do the same calculations for binomial distribution
sizes=2000/(np.array(range(1,100)+[10]))

# %%
md['binomial']={}

# %%
#values change depending on the scale in this example it accepted as 1
for n in sizes:
    md['binomial'][n]= np.random.binomial(mymean,1,100)

# %%
means = {}
means['binomial'] = {}

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['binomial'].iterkeys():
    means['binomial'][nn] = md['binomial'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['binomial'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['binomial']:
    allmeans.append(means['binomial'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
#standard gamma distribution
#do the same calculations for standard gamma distribution
sizes=2000/(np.array(range(1,100)+[10]))

# %%
md['stdgamma']={}

# %%
for n in sizes:
    md['stdgamma'][n]= np.random.standard_gamma(mymean,100)

# %%
means = {}
means['stdgamma'] = {}

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['stdgamma'].iterkeys():
    means['stdgamma'][nn] = md['stdgamma'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['stdgamma'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['stdgamma']:
    allmeans.append(means['stdgamma'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %%
#standard gumbel distribution
#do the same calculations for standard gumbel distribution
sizes=2000/(np.array(range(1,100)+[10]))

# %%
md['gm']={}

# %%
for n in sizes:
    md['gm'][n]= np.random.gumbel(mymean,100,100)

# %%
means = {}
means['gm'] = {}

# %%
fig_mu_N = pl.figure(figsize=(10,10))
axchisq_mu_n = fig_mu_N.add_subplot(111)
for nn in md['gm'].iterkeys():
    means['gm'][nn] = md['gm'][nn].mean()
    #and plot it
    axchisq_mu_n.plot(nn, means['gm'][nn], 'o')
    axchisq_mu_n.set_xlabel('sample size')
    axchisq_mu_n.set_ylabel('sample mean')
    axchisq_mu_n.plot([min(sizes), max(sizes)],[100,100], 'k')

# %%
allmeans=[]
for n in means['gm']:
    allmeans.append(means['gm'][n])
pl.figure(figsize=(10,10))
pl.hist(allmeans,bins=30)
pl.xlabel('sample mean')
pl.ylabel('N')

# %% [markdown]
# Binomial and gumbel distribution mainly different than others. Sample mean in same in binomial distribition and the in the gumbel distribution sample means becaome greater than the predifined mean.

# %% [markdown]
# # OPTIONAL QUESTION

# %%
# %pylab inline
# %matplotlib

from scipy.stats import norm
from numpy import linspace
from pylab import plot,show,hist,figure,title

# picking 150 of from a normal distrubution
# with mean 0 and standard deviation 1
samp = norm.rvs(loc=100,scale=50,size=100) 

param = norm.fit(samp) # distribution fitting

# now, param[0] and param[1] are the mean and 
# the standard deviation of the fitted distribution
x = linspace(10,2000,100)
# fitted distribution
pdf_fitted = norm.pdf(x,loc=param[0],scale=param[1])
# original distribution
pdf = norm.pdf(x)

title('Normal distribution')
plot(x,pdf_fitted,'r-',x,pdf,'b-')
hist(samp,normed=1,alpha=.3)
show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Using matplotlib backend: Qt4Agg
